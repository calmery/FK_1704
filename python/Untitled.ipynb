# %%
import numpy as np
import matplotlib.pyplot as plt
import PIL
# %matplotlib inline 

zero = np.load('numbers/0.npy')
one = np.load('numbers/1.npy')
plt.legend()
plt.plot(one[0], label="X")
plt.plot(one[1], label="Y")
plt.plot(one[2], label="Z")
plt.show()
# Out:
# /Users/toyotakeisuke/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
